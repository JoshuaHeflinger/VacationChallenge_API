# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,

                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | pahrump
# Processing Record 3 of Set 1 | kimberley
# Processing Record 4 of Set 1 | lichinga
# Processing Record 5 of Set 1 | gat
# Processing Record 6 of Set 1 | namibe
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | souillac
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | asyut
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | coquimbo
# Processing Record 17 of Set 1 | kavieng
# Processing Record 18 of Set 1 | kirakira
# Processing Record 19 of Set 1 | zuwarah
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | ahipara
# Processing Record 25 of Set 1 | sayansk
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | ola
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | grand-santi
# Processing Record 31 of Set 1 | kloulklubed
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | selishche
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | boa vista
# Processing Record 37 of Set 1 | takaka
# Processing Record 38 of Set 1 | pelym
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | machali
# Processing Record 44 of Set 1 | tuatapere
# Processing Record 45 of Set 1 | ilebo
# Processing Record 46 of Set 1 | mutsu
# Processing Record 47 of Set 1 | tazovskiy
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | rayong
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | mandera
# Processing Record 4 of Set 2 | batagay-alyta
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | grand forks
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | kampong thum
# Processing Record 11 of Set 2 | haapiti
# Processing Record 12 of Set 2 | nago
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | alofi
# Processing Record 15 of Set 2 | kismayo
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | zhigansk
# Processing Record 18 of Set 2 | aguimes
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | la union
# Processing Record 21 of Set 2 | vanimo
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | wajir
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | tukums
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | astoria
# Processing Record 29 of Set 2 | cochrane
# Processing Record 30 of Set 2 | gannan
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | zelenoborskiy
# Processing Record 33 of Set 2 | muisne
# Processing Record 34 of Set 2 | avera
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | talgar
# Processing Record 37 of Set 2 | namatanai
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | pacific grove
# Processing Record 42 of Set 2 | payo
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 2 | vaitape
# Processing Record 45 of Set 2 | sevsk
# Processing Record 46 of Set 2 | constitucion
# Processing Record 47 of Set 2 | merauke
# Processing Record 48 of Set 2 | akyab
# Processing Record 49 of Set 2 | bogoslovka
# Processing Record 50 of Set 2 | port alfred
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | karratha
# Processing Record 3 of Set 3 | chadiza
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 3 | da nang
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | mbaiki
# Processing Record 9 of Set 3 | marawi
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | waddan
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | kotovo
# Processing Record 14 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 3 | labuhan
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | ikongo
# Processing Record 18 of Set 3 | moree
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | birin
# Processing Record 22 of Set 3 | suba
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | castro
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | amahai
# Processing Record 27 of Set 3 | kudahuvadhoo
# Processing Record 28 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 3 | columbia
# Processing Record 30 of Set 3 | nusaybin
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | ozinki
# Processing Record 33 of Set 3 | langangen
# City not found. Skipping...
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | richards bay
# Processing Record 36 of Set 3 | chama
# Processing Record 37 of Set 3 | agadir
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | kuhestan
# City not found. Skipping...
# Processing Record 40 of Set 3 | luba
# Processing Record 41 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | augusto correa
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 3 | sterling
# Processing Record 47 of Set 3 | asfi
# Processing Record 48 of Set 3 | comodoro rivadavia
# Processing Record 49 of Set 3 | pafos
# Processing Record 50 of Set 3 | mvangue
# Processing Record 1 of Set 4 | haines junction
# Processing Record 2 of Set 4 | alvdal
# Processing Record 3 of Set 4 | san quintin
# Processing Record 4 of Set 4 | vestmannaeyjar
# Processing Record 5 of Set 4 | rosetta
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | baie-comeau
# Processing Record 9 of Set 4 | yeppoon
# Processing Record 10 of Set 4 | bonthe
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | hobart
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | pachmarhi
# Processing Record 15 of Set 4 | denau
# City not found. Skipping...
# Processing Record 16 of Set 4 | bud
# Processing Record 17 of Set 4 | posse
# Processing Record 18 of Set 4 | camacha
# Processing Record 19 of Set 4 | cockburn town
# Processing Record 20 of Set 4 | bonavista
# Processing Record 21 of Set 4 | horasan
# Processing Record 22 of Set 4 | trelew
# Processing Record 23 of Set 4 | xai-xai
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 4 | abu samrah
# Processing Record 27 of Set 4 | bilibino
# Processing Record 28 of Set 4 | ivybridge
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | leshukonskoye
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | saint-augustin
# Processing Record 34 of Set 4 | mecca
# Processing Record 35 of Set 4 | urubicha
# Processing Record 36 of Set 4 | jalu
# Processing Record 37 of Set 4 | lashio
# Processing Record 38 of Set 4 | pala
# Processing Record 39 of Set 4 | isangel
# Processing Record 40 of Set 4 | thai nguyen
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | port moresby
# Processing Record 43 of Set 4 | maceio
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | roald
# Processing Record 46 of Set 4 | tasiilaq
# Processing Record 47 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 4 | pitimbu
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | orlik
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 5 | kaeo
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | port-gentil
# Processing Record 6 of Set 5 | pecos
# Processing Record 7 of Set 5 | sakaiminato
# Processing Record 8 of Set 5 | nouadhibou
# Processing Record 9 of Set 5 | kyshtovka
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | umm jarr
# City not found. Skipping...
# Processing Record 12 of Set 5 | prince rupert
# Processing Record 13 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 5 | nueva gerona
# Processing Record 15 of Set 5 | tiarei
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | kruisfontein
# Processing Record 20 of Set 5 | ellisras
# Processing Record 21 of Set 5 | alyangula
# Processing Record 22 of Set 5 | eyl
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | bilma
# Processing Record 25 of Set 5 | palmer
# Processing Record 26 of Set 5 | verkhnyaya sinyachikha
# Processing Record 27 of Set 5 | arraial do cabo
# Processing Record 28 of Set 5 | dwarka
# Processing Record 29 of Set 5 | nioki
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | evensk
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | maxixe
# Processing Record 34 of Set 5 | shieli
# Processing Record 35 of Set 5 | beringovskiy
# Processing Record 36 of Set 5 | prainha
# Processing Record 37 of Set 5 | saint-andre-avellin
# Processing Record 38 of Set 5 | lannion
# Processing Record 39 of Set 5 | airai
# Processing Record 40 of Set 5 | hastings
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | lompoc
# Processing Record 43 of Set 5 | nishihara
# Processing Record 44 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 5 | kushiro
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | belmonte
# Processing Record 48 of Set 5 | codrington
# Processing Record 49 of Set 5 | khurda
# Processing Record 50 of Set 5 | tabuk
# Processing Record 1 of Set 6 | ulaangom
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 6 | okhotsk
# Processing Record 5 of Set 6 | iquique
# Processing Record 6 of Set 6 | berlevag
# Processing Record 7 of Set 6 | alta floresta
# Processing Record 8 of Set 6 | kutum
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | pandan
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | praya
# Processing Record 14 of Set 6 | sao filipe
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | yaan
# Processing Record 17 of Set 6 | santa ines
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | reconquista
# Processing Record 20 of Set 6 | saint-pierre
# Processing Record 21 of Set 6 | wajima
# Processing Record 22 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 6 | antofagasta
# Processing Record 24 of Set 6 | meulaboh
# Processing Record 25 of Set 6 | ballachulish
# Processing Record 26 of Set 6 | panaba
# Processing Record 27 of Set 6 | tricase
# Processing Record 28 of Set 6 | turayf
# Processing Record 29 of Set 6 | kisarawe
# Processing Record 30 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | palmas de monte alto
# Processing Record 33 of Set 6 | san juan bautista
# Processing Record 34 of Set 6 | bemidji
# Processing Record 35 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | svetlyy
# Processing Record 38 of Set 6 | nantucket
# Processing Record 39 of Set 6 | axim
# Processing Record 40 of Set 6 | port hedland
# Processing Record 41 of Set 6 | malanje
# Processing Record 42 of Set 6 | olinda
# Processing Record 43 of Set 6 | riverton
# Processing Record 44 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 45 of Set 6 | hami
# Processing Record 46 of Set 6 | pangnirtung
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 6 | sebinkarahisar
# Processing Record 50 of Set 6 | pokosnoye
# Processing Record 1 of Set 7 | tulun
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | saint-georges
# Processing Record 4 of Set 7 | lokomotivnyy
# Processing Record 5 of Set 7 | port macquarie
# Processing Record 6 of Set 7 | along
# Processing Record 7 of Set 7 | whitehorse
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 7 | uige
# Processing Record 11 of Set 7 | pimenteiras
# Processing Record 12 of Set 7 | puerto cortes
# City not found. Skipping...
# Processing Record 13 of Set 7 | mugur-aksy
# Processing Record 14 of Set 7 | rawson
# Processing Record 15 of Set 7 | apac
# Processing Record 16 of Set 7 | turbat
# Processing Record 17 of Set 7 | katangli
# Processing Record 18 of Set 7 | imbituba
# Processing Record 19 of Set 7 | wageningen
# Processing Record 20 of Set 7 | upernavik
# Processing Record 21 of Set 7 | kashi
# Processing Record 22 of Set 7 | kozlovka
# Processing Record 23 of Set 7 | chumikan
# Processing Record 24 of Set 7 | hyeres
# Processing Record 25 of Set 7 | morgantown
# Processing Record 26 of Set 7 | ahuimanu
# Processing Record 27 of Set 7 | santarem
# Processing Record 28 of Set 7 | morro bay
# Processing Record 29 of Set 7 | dikson
# Processing Record 30 of Set 7 | tuntum
# Processing Record 31 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 32 of Set 7 | olafsvik
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | pathein
# Processing Record 36 of Set 7 | carnarvon
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | minsk
# Processing Record 39 of Set 7 | baruun-urt
# Processing Record 40 of Set 7 | cap malheureux
# Processing Record 41 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 7 | bereda
# Processing Record 43 of Set 7 | agua dulce
# Processing Record 44 of Set 7 | fredericton
# Processing Record 45 of Set 7 | vredendal
# Processing Record 46 of Set 7 | springbok
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | altus
# Processing Record 49 of Set 7 | mao
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | yumen
# Processing Record 2 of Set 8 | osorno
# Processing Record 3 of Set 8 | bom jesus
# Processing Record 4 of Set 8 | natchez
# Processing Record 5 of Set 8 | moerai
# Processing Record 6 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | viking
# Processing Record 10 of Set 8 | uinskoye
# Processing Record 11 of Set 8 | paracuru
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | burnie
# Processing Record 14 of Set 8 | bengkulu
# Processing Record 15 of Set 8 | medicine hat
# Processing Record 16 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 8 | sanguem
# Processing Record 18 of Set 8 | luderitz
# Processing Record 19 of Set 8 | asau
# Processing Record 20 of Set 8 | amapa
# Processing Record 21 of Set 8 | darhan
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | gamba
# Processing Record 24 of Set 8 | opuwo
# Processing Record 25 of Set 8 | bafia
# Processing Record 26 of Set 8 | senanga
# Processing Record 27 of Set 8 | maracaibo
# Processing Record 28 of Set 8 | banyuwangi
# Processing Record 29 of Set 8 | padang
# Processing Record 30 of Set 8 | cherskiy
# Processing Record 31 of Set 8 | praia da vitoria
# Processing Record 32 of Set 8 | kahului
# Processing Record 33 of Set 8 | sorbhog
# Processing Record 34 of Set 8 | kabare
# Processing Record 35 of Set 8 | hengyang
# Processing Record 36 of Set 8 | mtambile
# Processing Record 37 of Set 8 | pizhanka
# Processing Record 38 of Set 8 | rocha
# Processing Record 39 of Set 8 | alpena
# Processing Record 40 of Set 8 | severnyy
# Processing Record 41 of Set 8 | bodden town
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | altay
# Processing Record 44 of Set 8 | saint-philippe
# Processing Record 45 of Set 8 | raudeberg
# Processing Record 46 of Set 8 | porto novo
# Processing Record 47 of Set 8 | caceres
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | peniche
# Processing Record 50 of Set 8 | fort-shevchenko
# Processing Record 1 of Set 9 | angoram
# Processing Record 2 of Set 9 | ixtapa
# Processing Record 3 of Set 9 | flin flon
# Processing Record 4 of Set 9 | gazojak
# Processing Record 5 of Set 9 | riyadh
# Processing Record 6 of Set 9 | bayonet point
# Processing Record 7 of Set 9 | hanzhong
# Processing Record 8 of Set 9 | mandalgovi
# Processing Record 9 of Set 9 | dargaville
# Processing Record 10 of Set 9 | mantua
# Processing Record 11 of Set 9 | ovalle
# Processing Record 12 of Set 9 | twentynine palms
# Processing Record 13 of Set 9 | san policarpo
# Processing Record 14 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 9 | rodrigues alves
# Processing Record 16 of Set 9 | grindavik
# Processing Record 17 of Set 9 | cayenne
# Processing Record 18 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 9 | gallup
# Processing Record 20 of Set 9 | mokhsogollokh
# Processing Record 21 of Set 9 | biu
# Processing Record 22 of Set 9 | dhidhdhoo
# Processing Record 23 of Set 9 | itaquyry
# Processing Record 24 of Set 9 | sao jose da coroa grande
# Processing Record 25 of Set 9 | killybegs
# Processing Record 26 of Set 9 | somerset
# Processing Record 27 of Set 9 | makakilo city
# Processing Record 28 of Set 9 | cururupu
# Processing Record 29 of Set 9 | isabela
# Processing Record 30 of Set 9 | hirara
# Processing Record 31 of Set 9 | trincomalee
# Processing Record 32 of Set 9 | griffith
# Processing Record 33 of Set 9 | phnum penh
# City not found. Skipping...
# Processing Record 34 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 9 | palmares do sul
# Processing Record 36 of Set 9 | jaguaribe
# Processing Record 37 of Set 9 | olmos
# Processing Record 38 of Set 9 | nemuro
# Processing Record 39 of Set 9 | jesup
# Processing Record 40 of Set 9 | bandarbeyla
# Processing Record 41 of Set 9 | kindu
# Processing Record 42 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 9 | smalininkai
# Processing Record 44 of Set 9 | aktash
# Processing Record 45 of Set 9 | laguna
# Processing Record 46 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 9 | homer
# Processing Record 48 of Set 9 | baykit
# Processing Record 49 of Set 9 | chokurdakh
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | kazachinskoye
# Processing Record 2 of Set 10 | guanay
# Processing Record 3 of Set 10 | yerbogachen
# Processing Record 4 of Set 10 | vila velha
# Processing Record 5 of Set 10 | puerto escondido
# Processing Record 6 of Set 10 | jales
# Processing Record 7 of Set 10 | belaya gora
# Processing Record 8 of Set 10 | nioro
# Processing Record 9 of Set 10 | san patricio
# Processing Record 10 of Set 10 | wattegama
# Processing Record 11 of Set 10 | filingue
# Processing Record 12 of Set 10 | kashary
# Processing Record 13 of Set 10 | corn island
# Processing Record 14 of Set 10 | rosiile
# Processing Record 15 of Set 10 | buraydah
# Processing Record 16 of Set 10 | geraldton
# Processing Record 17 of Set 10 | rio grande
# Processing Record 18 of Set 10 | rio brilhante
# Processing Record 19 of Set 10 | kempsey
# Processing Record 20 of Set 10 | le port
# Processing Record 21 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 10 | lucapa
# Processing Record 23 of Set 10 | cruz grande
# Processing Record 24 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 25 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | hatillo
# Processing Record 28 of Set 10 | jurm
# Processing Record 29 of Set 10 | yulara
# Processing Record 30 of Set 10 | alice springs
# Processing Record 31 of Set 10 | male
# Processing Record 32 of Set 10 | keetmanshoop
# Processing Record 33 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 34 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 10 | kenai
# Processing Record 37 of Set 10 | huilong
# Processing Record 38 of Set 10 | katherine
# Processing Record 39 of Set 10 | colares
# Processing Record 40 of Set 10 | mayo
# Processing Record 41 of Set 10 | lata
# Processing Record 42 of Set 10 | seoul
# Processing Record 43 of Set 10 | malinovoye ozero
# Processing Record 44 of Set 10 | lodwar
# Processing Record 45 of Set 10 | pimenta bueno
# Processing Record 46 of Set 10 | gannavaram
# Processing Record 47 of Set 10 | grand gaube
# Processing Record 48 of Set 10 | sayyan
# Processing Record 49 of Set 10 | la palma
# Processing Record 50 of Set 10 | luganville
# Processing Record 1 of Set 11 | maine-soroa
# Processing Record 2 of Set 11 | seminole
# Processing Record 3 of Set 11 | buchanan
# Processing Record 4 of Set 11 | balykshi
# Processing Record 5 of Set 11 | mahebourg
# Processing Record 6 of Set 11 | watertown
# Processing Record 7 of Set 11 | kavali
# Processing Record 8 of Set 11 | casma
# Processing Record 9 of Set 11 | komyshuvakha
# Processing Record 10 of Set 11 | kingsland
# Processing Record 11 of Set 11 | kijaba
# City not found. Skipping...
# Processing Record 12 of Set 11 | los llanos de aridane
# Processing Record 13 of Set 11 | agua buena
# Processing Record 14 of Set 11 | havre-saint-pierre
# Processing Record 15 of Set 11 | corsicana
# Processing Record 16 of Set 11 | saint-joseph
# Processing Record 17 of Set 11 | tautira
# Processing Record 18 of Set 11 | ostrovnoy
# Processing Record 19 of Set 11 | port hardy
# Processing Record 20 of Set 11 | boyolangu
# Processing Record 21 of Set 11 | ladybrand
# Processing Record 22 of Set 11 | roma
# Processing Record 23 of Set 11 | nedjo
# Processing Record 24 of Set 11 | port lincoln
# Processing Record 25 of Set 11 | fereydun kenar
# Processing Record 26 of Set 11 | kavaratti
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 11 | katsuura
# Processing Record 30 of Set 11 | nelson bay
# Processing Record 31 of Set 11 | sembe
# Processing Record 32 of Set 11 | atbasar
# Processing Record 33 of Set 11 | muravlenko
# Processing Record 34 of Set 11 | sitrah
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | bozhou
# Processing Record 37 of Set 11 | backa topola
# Processing Record 38 of Set 11 | jizan
# Processing Record 39 of Set 11 | tarabuco
# Processing Record 40 of Set 11 | ajaccio
# Processing Record 41 of Set 11 | tutayev
# Processing Record 42 of Set 11 | hoi an
# Processing Record 43 of Set 11 | sungairaya
# Processing Record 44 of Set 11 | mangrol
# Processing Record 45 of Set 11 | provideniya
# Processing Record 46 of Set 11 | markova
# Processing Record 47 of Set 11 | makhalino
# Processing Record 48 of Set 11 | yining
# Processing Record 49 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 50 of Set 11 | heiligenhafen
# Processing Record 1 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 12 | lodja
# Processing Record 3 of Set 12 | pemangkat
# Processing Record 4 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 5 of Set 12 | bakaly
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | ampanihy
# Processing Record 8 of Set 12 | naryan-mar
# Processing Record 9 of Set 12 | kourou
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | bontang
# Processing Record 12 of Set 12 | ramhormoz
# Processing Record 13 of Set 12 | carbonia
# Processing Record 14 of Set 12 | kupang
# Processing Record 15 of Set 12 | shakiso
# Processing Record 16 of Set 12 | marv dasht
# City not found. Skipping...
# Processing Record 17 of Set 12 | muskegon
# Processing Record 18 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 12 | vorkuta
# Processing Record 20 of Set 12 | ngunguru
# Processing Record 21 of Set 12 | vanavara
# Processing Record 22 of Set 12 | mandali
# Processing Record 23 of Set 12 | nagato
# Processing Record 24 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 25 of Set 12 | kizema
# Processing Record 26 of Set 12 | bad neustadt
# City not found. Skipping...
# Processing Record 27 of Set 12 | matucana
# Processing Record 28 of Set 12 | upata
# Processing Record 29 of Set 12 | gharghoda
# Processing Record 30 of Set 12 | turukhansk
# Processing Record 31 of Set 12 | kilindoni
# Processing Record 32 of Set 12 | konitsa
# Processing Record 33 of Set 12 | ibra
# Processing Record 34 of Set 12 | brownsville
# Processing Record 35 of Set 12 | wangqing
# Processing Record 36 of Set 12 | banda aceh
# Processing Record 37 of Set 12 | villa bruzual
# Processing Record 38 of Set 12 | fethiye
# Processing Record 39 of Set 12 | lubango
# Processing Record 40 of Set 12 | secunda
# Processing Record 41 of Set 12 | kyren
# Processing Record 42 of Set 12 | poum
# Processing Record 43 of Set 12 | bubaque
# Processing Record 44 of Set 12 | valdivia
# Processing Record 45 of Set 12 | piacabucu
# Processing Record 46 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 47 of Set 12 | tirodi
# Processing Record 48 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 12 | coahuayana
# Processing Record 50 of Set 12 | opelousas
# Processing Record 1 of Set 13 | neuquen
# Processing Record 2 of Set 13 | camden
# Processing Record 3 of Set 13 | pinawa
# Processing Record 4 of Set 13 | lethem
# Processing Record 5 of Set 13 | jacqueville
# Processing Record 6 of Set 13 | shimoda
# Processing Record 7 of Set 13 | dalby
# Processing Record 8 of Set 13 | manakara
# Processing Record 9 of Set 13 | sola
# Processing Record 10 of Set 13 | chulym
# Processing Record 11 of Set 13 | portland
# Processing Record 12 of Set 13 | booue
# Processing Record 13 of Set 13 | georgetown
# Processing Record 14 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 15 of Set 13 | loralai
# Processing Record 16 of Set 13 | miraflores
# Processing Record 17 of Set 13 | turinskaya sloboda
# Processing Record 18 of Set 13 | lewistown
# Processing Record 19 of Set 13 | sorong
# Processing Record 20 of Set 13 | salinas
# Processing Record 21 of Set 13 | lasa
# Processing Record 22 of Set 13 | gizo
# Processing Record 23 of Set 13 | ula
# Processing Record 24 of Set 13 | san juan del sur
# Processing Record 25 of Set 13 | mutum
# Processing Record 26 of Set 13 | san cristobal
# Processing Record 27 of Set 13 | kristinehamn
# Processing Record 28 of Set 13 | mayumba
# Processing Record 29 of Set 13 | the valley
# Processing Record 30 of Set 13 | manggar
# Processing Record 31 of Set 13 | teguise
# Processing Record 32 of Set 13 | sept-iles
# Processing Record 33 of Set 13 | paamiut
# Processing Record 34 of Set 13 | antalaha
# Processing Record 35 of Set 13 | willowmore
# Processing Record 36 of Set 13 | thalgau
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | monrovia
# Processing Record 39 of Set 13 | inongo
# Processing Record 40 of Set 13 | tecoanapa
# Processing Record 41 of Set 13 | manzil salim
# Processing Record 42 of Set 13 | praxedis guerrero
# Processing Record 43 of Set 13 | kinwat
# Processing Record 44 of Set 13 | vagay
# Processing Record 45 of Set 13 | trairi
# Processing Record 46 of Set 13 | valparaiso
# Processing Record 47 of Set 13 | lanxi
# Processing Record 48 of Set 13 | brejo
# Processing Record 49 of Set 13 | ayna
# Processing Record 50 of Set 13 | buala
# Processing Record 1 of Set 14 | gigmoto
# Processing Record 2 of Set 14 | salinopolis
# Processing Record 3 of Set 14 | waipawa
# Processing Record 4 of Set 14 | kantemirovka
# Processing Record 5 of Set 14 | metkovic
# Processing Record 6 of Set 14 | kununurra
# Processing Record 7 of Set 14 | mwinilunga
# Processing Record 8 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 14 | armenion
# City not found. Skipping...
# Processing Record 10 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 14 | doka
# Processing Record 12 of Set 14 | safaga
# Processing Record 13 of Set 14 | jiujiang
# Processing Record 14 of Set 14 | aykhal
# Processing Record 15 of Set 14 | san andres
# Processing Record 16 of Set 14 | dzaoudzi
# Processing Record 17 of Set 14 | hovd
# Processing Record 18 of Set 14 | strezhevoy
# Processing Record 19 of Set 14 | whitianga
# Processing Record 20 of Set 14 | balakovo
# Processing Record 21 of Set 14 | sur
# Processing Record 22 of Set 14 | tura
# Processing Record 23 of Set 14 | kieta
# Processing Record 24 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | lieksa
# Processing Record 26 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 14 | kidal
# Processing Record 28 of Set 14 | srednekolymsk
# Processing Record 29 of Set 14 | lao cai
# Processing Record 30 of Set 14 | bellefontaine
# Processing Record 31 of Set 14 | vangaindrano
# Processing Record 32 of Set 14 | pavilosta
# Processing Record 33 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 14 | shakhtinsk
# Processing Record 35 of Set 14 | usvyaty
# Processing Record 36 of Set 14 | jiangyan
# Processing Record 37 of Set 14 | hofn
# Processing Record 38 of Set 14 | plettenberg bay
# Processing Record 39 of Set 14 | kubrat
# Processing Record 40 of Set 14 | chachapoyas
# Processing Record 41 of Set 14 | lazaro cardenas
# Processing Record 42 of Set 14 | muroto
# Processing Record 43 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 14 | botesti
# Processing Record 45 of Set 14 | zhuzhou
# Processing Record 46 of Set 14 | zermatt
# Processing Record 47 of Set 14 | fukue
# Processing Record 48 of Set 14 | tadine
# Processing Record 49 of Set 14 | andenes
# Processing Record 50 of Set 14 | elista
# Processing Record 1 of Set 15 | jumilla
# Processing Record 2 of Set 15 | adrar
# Processing Record 3 of Set 15 | ye
# City not found. Skipping...
# Processing Record 4 of Set 15 | goedereede
# Processing Record 5 of Set 15 | kolondieba
# Processing Record 6 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 15 | catamarca
# Processing Record 8 of Set 15 | clyde river
# Processing Record 9 of Set 15 | sechura
# Processing Record 10 of Set 15 | condado
# Processing Record 11 of Set 15 | quatre cocos
# Processing Record 12 of Set 15 | quelimane
# Processing Record 13 of Set 15 | arlit
# Processing Record 14 of Set 15 | columbus
# Processing Record 15 of Set 15 | alekseyevsk
# Processing Record 16 of Set 15 | flinders
# Processing Record 17 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 18 of Set 15 | akureyri
# Processing Record 19 of Set 15 | perelyub
# Processing Record 20 of Set 15 | maniwaki
# Processing Record 21 of Set 15 | port augusta
# Processing Record 22 of Set 15 | cacule
# Processing Record 23 of Set 15 | locri
# Processing Record 24 of Set 15 | abeche
# Processing Record 25 of Set 15 | maldonado
# Processing Record 26 of Set 15 | jaffna
# Processing Record 27 of Set 15 | udachnyy
# Processing Record 28 of Set 15 | qaqortoq
# Processing Record 29 of Set 15 | byron bay
# Processing Record 30 of Set 15 | saint anthony
# Processing Record 31 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 15 | bakonycsernye
# Processing Record 33 of Set 15 | berezovyy
# Processing Record 34 of Set 15 | ganzhou
# Processing Record 35 of Set 15 | may pen
# Processing Record 36 of Set 15 | acarau
# Processing Record 37 of Set 15 | lamu
# Processing Record 38 of Set 15 | hargeysa
# Processing Record 39 of Set 15 | half moon bay
# Processing Record 40 of Set 15 | akhmeta
# Processing Record 41 of Set 15 | orotukan
# Processing Record 42 of Set 15 | woodward
# Processing Record 43 of Set 15 | aksarayskiy
# Processing Record 44 of Set 15 | viedma
# Processing Record 45 of Set 15 | osa
# Processing Record 46 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 47 of Set 15 | yasu
# Processing Record 48 of Set 15 | sao joao da barra
# Processing Record 49 of Set 15 | casa nova
# Processing Record 50 of Set 15 | buriti bravo
# Processing Record 1 of Set 16 | fianga
# City not found. Skipping...
# Processing Record 2 of Set 16 | melilla
# Processing Record 3 of Set 16 | marsabit
# Processing Record 4 of Set 16 | santa comba
# Processing Record 5 of Set 16 | lyuban
# Processing Record 6 of Set 16 | edd
# Processing Record 7 of Set 16 | ekuvukeni
# Processing Record 8 of Set 16 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 16 | kramat
# Processing Record 10 of Set 16 | den helder
# Processing Record 11 of Set 16 | general jose eduvigis diaz
# Processing Record 12 of Set 16 | humaita
# Processing Record 13 of Set 16 | aquin
# Processing Record 14 of Set 16 | bonga
# Processing Record 15 of Set 16 | lavrentiya
# Processing Record 16 of Set 16 | bossembele
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.0752 -159.3190     69.78        88           0
# 1       Pahrump      US  36.2083 -115.9839     44.65        39          85
# 2     Kimberley      ZA -28.7323   24.7623     86.65        13           0
# 3      Lichinga      MZ -13.3128   35.2406     63.45        96          99
# 4           Gat      IL  31.6100   34.7642     54.28       100          18
# 5        Namibe      AO -15.1961   12.1522     76.01        75          25
# 6       Ushuaia      AR -54.8000  -68.3000     56.82        62          75
# 7      Souillac      MU -20.5167   57.5167     79.18        78          40
# 8     Ilulissat      GL  69.2167  -51.1000      1.42        39          15
# 9  Punta Arenas      CL -53.1500  -70.9167     51.91        54          40
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1        2.77     overcast clouds
# 2       11.65           clear sky
# 3        2.95          light rain
# 4       18.86          few clouds
# 5       11.41    scattered clouds
# 6       26.46       broken clouds
# 7        5.75    scattered clouds
# 8        0.00          few clouds
# 9       43.73    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df
# Out:
#                            City Country      Lat       Lng  Max Temp  \
# 0                         Kapaa      US  22.0752 -159.3190     69.78
# 1                       Pahrump      US  36.2083 -115.9839     44.65
# 2                     Kimberley      ZA -28.7323   24.7623     86.65
# 3                      Lichinga      MZ -13.3128   35.2406     63.45
# 4                           Gat      IL  31.6100   34.7642     54.28
# ..                          ...     ...      ...       ...       ...
# 688  General Jose Eduvigis Diaz      PY -27.1667  -58.4167     84.24
# 689                     Humaita      BR  -7.5061  -63.0208     88.83
# 690                       Aquin      HT  18.2833  -73.4000     81.68
# 691                       Bonga      ET   7.2833   36.2333     61.88
# 692                  Lavrentiya      RU  65.5833 -171.0000      2.44
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          88           0        6.91           clear sky
# 1          39          85        2.77     overcast clouds
# 2          13           0       11.65           clear sky
# 3          96          99        2.95          light rain
# 4         100          18       18.86          few clouds
# ..        ...         ...         ...                 ...
# 688        31          43        9.01          light rain
# 689        56          94        2.66     overcast clouds
# 690        63           0        4.97           clear sky
# 691        92          76        0.20          light rain
# 692        92          12       12.03          few clouds
#
# [693 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = 'WeatherPy_Database.csv'
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file,index = False)
